# %%
# !pip install ultralytics roboflow -q

# %%
from ultralytics import YOLO
from roboflow import Roboflow
import os

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3R1ouxWcBN8lEgYROMAQ")
project = rf.workspace("harsh994969-gmail-com").project("skin-lesion-detection-dnuq9-yrzo2")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3R1ouxWcBN8lEgYROMAQ")
project = rf.workspace("harsh994969-gmail-com").project("skin-lesion-detection-dnuq9-yrzo2")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Skin-Lesion-Detection-1 in yolov8:: 100%|██████████| 3639/3639 [00:00<00:00, 8154.96it/s]

# %%
import os

print(dataset.location)

print(os.listdir(dataset.location))
# Out:
# /content/Skin-Lesion-Detection-1
# ['valid', 'README.roboflow.txt', 'data.yaml', 'train', 'README.dataset.txt', 'test']

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

# %%
results = model.train(
    data="/content/Skin-Lesion-Detection-1/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    project="SkinLesionYOLO",
    name="SkinLesion",
    device=0
)
# Out:
# Ultralytics 8.4.104 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from IPython.display import Image, display

display(Image("/content/runs/detect/SkinLesionYOLO/SkinLesion/results.png"))

# %%
display(Image("/content/runs/detect/SkinLesionYOLO/SkinLesion/confusion_matrix.png"))

# %%
display(Image("/content/runs/detect/SkinLesionYOLO/SkinLesion/confusion_matrix_normalized.png"))

# %%
import os

folder = "/content/runs/detect/SkinLesionYOLO/SkinLesion"

for file in sorted(os.listdir(folder)):
    print(file)
# Out:
# BoxF1_curve.png
# BoxPR_curve.png
# BoxP_curve.png
# BoxR_curve.png
# args.yaml
# confusion_matrix.png
# confusion_matrix_normalized.png
# labels.jpg
# results.csv
# results.png
# train_batch0.jpg
# train_batch1.jpg
# train_batch2.jpg
# train_batch3840.jpg
# train_batch3841.jpg
# train_batch3842.jpg
# val_batch0_labels.jpg
# val_batch0_pred.jpg
# val_batch1_labels.jpg
# val_batch1_pred.jpg
# val_batch2_labels.jpg
# val_batch2_pred.jpg
# weights

# %%
from IPython.display import Image, display

display(Image("/content/runs/detect/SkinLesionYOLO/SkinLesion/results.png"))

# %%
display(Image("/content/runs/detect/SkinLesionYOLO/SkinLesion/BoxPR_curve.png"))

# %%
display(Image("/content/runs/detect/SkinLesionYOLO/SkinLesion/BoxF1_curve.png"))

# %%
display(Image("/content/runs/detect/SkinLesionYOLO/SkinLesion/BoxP_curve.png"))

# %%
display(Image("/content/runs/detect/SkinLesionYOLO/SkinLesion/BoxR_curve.png"))

# %%
display(Image("/content/runs/detect/SkinLesionYOLO/SkinLesion/confusion_matrix.png"))

# %%
display(Image("/content/runs/detect/SkinLesionYOLO/SkinLesion/confusion_matrix_normalized.png"))

# %%
display(Image("/content/runs/detect/SkinLesionYOLO/SkinLesion/val_batch0_pred.jpg"))

# %%
display(Image("/content/runs/detect/SkinLesionYOLO/SkinLesion/val_batch1_pred.jpg"))

# %%
display(Image("/content/runs/detect/SkinLesionYOLO/SkinLesion/val_batch2_pred.jpg"))

# %%
import shutil

shutil.make_archive(
    "/content/SkinLesionYOLO_Results",
    "zip",
    "/content/runs/detect/SkinLesionYOLO/SkinLesion"
)

print("ZIP file created successfully!")
# Out:
# ZIP file created successfully!

# %%
from google.colab import files

files.download("/content/SkinLesionYOLO_Results.zip")
